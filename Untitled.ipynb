# %%
import requests

URL = "https://www.goodreads.com/api/author_url/oscarwilde"
    KEY = "QLJcPV9A5Z6uC9yeped7Gg"

r = requests.get(URL, params={'key': KEY})
r.text
# Out:
# '<?xml version="1.0" encoding="UTF-8"?>\n<GoodreadsResponse>\n  <Request>\n    <authentication>true</authentication>\n      <key><![CDATA[QLJcPV9A5Z6uC9yeped7Gg]]></key>\n    <method><![CDATA[api_author_link]]></method>\n  </Request>\n  \n</GoodreadsResponse>'

# %%
import requests
res = requests.get("https://www.goodreads.com/book/review_counts.json", params={"key": KEY, "isbns": "9781632168146"})
print(res.json())
# Out:
# {'books': [{'text_reviews_count': 0, 'id': 29207858, 'work_text_reviews_count': 10, 'ratings_count': 0, 'average_rating': '4.07', 'reviews_count': 2, 'isbn': '1632168146', 'work_reviews_count': 123, 'isbn13': '9781632168146', 'work_ratings_count': 28}]}

# %%
import
# Out:
# 'not authorized\n<!-- This is a random-length HTML comment: ... -->'

# %%
from sqlalchemy import create_engine

URI = "postgres://blsjrqoxfgkayn:0fb42e7032fb368d9e3cb0410b52b74fd554cb5e9bebede68a65a594de33d7c3@ec2-176-34-183-20.eu-west-1.compute.amazonaws.com:5432/d5mm0dfva2naio"

engine = create_engine(URI)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-17-759976249e3b> in <module>
#       3 URI = "postgres://blsjrqoxfgkayn:0fb42e7032fb368d9e3cb0410b52b74fd554cb5e9bebede68a65a594de33d7c3@ec2-176-34-183-20.eu-west-1.compute.amazonaws.com:5432/d5mm0dfva2naio"
#       4
# ----> 5 engine = create_engine(URI)
#       6
#
# ~/ipython/venv/lib/python3.5/site-packages/sqlalchemy/engine/__init__.py in create_engine(*args, **kwargs)
#     477     strategy = kwargs.pop("strategy", default_strategy)
#     478     strategy = strategies.strategies[strategy]
# --> 479     return strategy.create(*args, **kwargs)
#     480
#     481
#
# ~/ipython/venv/lib/python3.5/site-packages/sqlalchemy/engine/strategies.py in create(self, name_or_url, **kwargs)
#      85                 if k in kwargs:
#      86                     dbapi_args[k] = pop_kwarg(k)
# ...

# %%
import csv

with open('books.csv', 'r') as f:
    x = csv.DictReader(f)
    z = dir(x)
    print(z)
#     for line in x:
#         print(line)
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__next__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_fieldnames', 'dialect', 'fieldnames', 'line_num', 'reader', 'restkey', 'restval']

# %%
import csv

with open('books.csv', 'r') as f:
    x = csv.reader(f)
    for a,b,c,d in x:
        print(a)
# Out:
# isbn
# 0380795272
# 1416949658
# 1857231082
# 0553803700
# 080213825X
# 0375913750
# 074349671X
# 0743454553
# 0765317508
# 0142501085
# 1442468351
# 1439152802
# 0399153942
# 0441017835
# 0590554107
# 1451648537
# 0590396560
# 000723368X
# 0803734735
# 1592243002
# 055337849X
# 0061150142
# 0739328271
# 0062076108
# 039925675X
# 1595543414
# 0446679097
# 0385339607
# 1250012570
# 0786838655
# 0440225450
# 0743484355
# 0670016780
# 0140621733
# 0061662763
# 006117758X
# 1423102266
# 067056172X
# 0385339097
# 0413757102
# 0441569595
# 0684833395
# 1416950737
# 0140501827
# 0099285444
# 0552555703
# 0671047345
# 0812995201
# 0812995341
# 0553589377
# 1476798176
# 0006640613
# 0395870828
# 1585678759
# 0425241130
# 0743417321
# 1598184318
# 0312571259
# 0345424646
# 0393062627
# 0312624670
# 0451235843
# 1400079497
# 1857988094
# 1423121309
# 0451169514
# 0061053562
# 0156949601
# 0446617792
# 0060096187
# 0345484088
# 0345379063
# 0060824972
# 0312932804
# 1857989341
# 0425234339
# ...
